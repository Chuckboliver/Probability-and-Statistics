# %%
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
data_set_path = "../data_set/pokemon_alopez247.csv"
df = pd.read_csv(data_set_path)
df_1 = df[["Name", "Height_m", "Weight_kg", "Body_Style"]]
df_1.head(n=30)
# Out:
#           Name  Height_m  Weight_kg       Body_Style
# 0    Bulbasaur      0.71        6.9        quadruped
# 1      Ivysaur      0.99       13.0        quadruped
# 2     Venusaur      2.01      100.0        quadruped
# 3   Charmander      0.61        8.5   bipedal_tailed
# 4   Charmeleon      1.09       19.0   bipedal_tailed
# 5    Charizard      1.70       90.5   bipedal_tailed
# 6     Squirtle      0.51        9.0   bipedal_tailed
# 7    Wartortle      0.99       22.5   bipedal_tailed
# 8    Blastoise      1.60       85.5   bipedal_tailed
# 9     Caterpie      0.30        2.9        insectoid
# 10     Metapod      0.71        9.9  serpentine_body
# 11  Butterfree      1.09       32.0       four_wings
# 12      Weedle      0.30        3.2  serpentine_body
# 13      Kakuna      0.61       10.0  serpentine_body
# 14    Beedrill      0.99       29.5       four_wings
# 15      Pidgey      0.30        1.8        two_wings
# 16   Pidgeotto      1.09       30.0        two_wings
# 17     Pidgeot      1.50       39.5        two_wings
# 18     Rattata      0.30        3.5        quadruped
# 19    Raticate      0.71       18.5        quadruped
# 20     Spearow      0.30        2.0        two_wings
# 21      Fearow      1.19       38.0        two_wings
# 22       Ekans      2.01        6.9  serpentine_body
# 23       Arbok      3.51       65.0  serpentine_body
# 24     Pikachu      0.41        6.0        quadruped
# 25      Raichu      0.79       30.0   bipedal_tailed
# 26   Sandshrew      0.61       12.0   bipedal_tailed
# 27   Sandslash      0.99       29.5   bipedal_tailed
# 28    Nidoran♀      0.41        7.0        quadruped
# 29    Nidorina      0.79       20.0        quadruped

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 721 entries, 0 to 720
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        721 non-null    object
#  1   Height_m    721 non-null    float64
#  2   Weight_kg   721 non-null    float64
#  3   Body_Style  721 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 22.7+ KB

# %%
df_1.describe()
# Out:
#          Height_m   Weight_kg
# count  721.000000  721.000000
# mean     1.144979   56.773370
# std      1.044369   89.095667
# min      0.100000    0.100000
# 25%      0.610000    9.400000
# 50%      0.990000   28.000000
# 75%      1.400000   61.000000
# max     14.500000  950.000000

# %%
nan_mask = df_1.isna().any(axis="columns")
df_1[nan_mask]
# Out:
# Empty DataFrame
# Columns: [Name, Height_m, Weight_kg, Body_Style]
# Index: []

# %%
ax = plt.gca()
df_1.iloc[:30].plot(kind="line", x="Name", y="Height_m", ax=ax)
df_1.iloc[:30].plot(kind="line", x="Name", y="Weight_kg", ax=ax, color="red")
plt.xticks(rotation=90)
plt.show()
